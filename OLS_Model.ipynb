# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
import pandas as pd

# %%
df = pd.read_csv('https://github.com/itsAkkil/Cgni-intrn/raw/main/Task-1/Dataset%20.csv')

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.Cuisines.unique()
# Out:
# array(['French, Japanese, Desserts', 'Japanese',
#        'Seafood, Asian, Filipino, Indian', ..., 'Burger, Izgara',
#        'World Cuisine, Patisserie, Cafe', 'Italian, World Cuisine'],
#       dtype=object)

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9542 non-null   int64
#  1   Restaurant Name       9542 non-null   object
#  2   Country Code          9542 non-null   int64
#  3   City                  9542 non-null   object
#  4   Address               9542 non-null   object
#  5   Locality              9542 non-null   object
#  6   Locality Verbose      9542 non-null   object
#  7   Longitude             9542 non-null   float64
#  8   Latitude              9542 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9542 non-null   int64
#  11  Currency              9542 non-null   object
#  12  Has Table booking     9542 non-null   object
#  13  Has Online delivery   9542 non-null   object
#  14  Is delivering now     9542 non-null   object
# ...

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
X = df[['Average Cost for two', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu',
       'Price range']]

y = df['Aggregate rating']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9542 entries, 0 to 9550
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Average Cost for two  9542 non-null   int64
#  1   Has Table booking     9542 non-null   object
#  2   Has Online delivery   9542 non-null   object
#  3   Is delivering now     9542 non-null   object
#  4   Switch to order menu  9542 non-null   object
#  5   Price range           9542 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 521.8+ KB

# %%
X.replace({'Has Table booking': {'Yes': 1, 'No': 0}}, inplace=True)
X.replace({'Has Online delivery': {'Yes': 1, 'No': 0}}, inplace=True)
X.replace({'Is delivering now': {'Yes': 1, 'No': 0}}, inplace=True)
X.replace({'Switch to order menu': {'Yes': 1, 'No': 0}}, inplace=True)
# Out:
# <ipython-input-11-a79b4215095d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace({'Has Table booking': {'Yes': 1, 'No': 0}}, inplace=True)
# <ipython-input-11-a79b4215095d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   X.replace({'Has Online delivery': {'Yes': 1, 'No': 0}}, inplace=True)
# <ipython-input-11-a79b4215095d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
X.head()
# Out:
#    Average Cost for two  Has Table booking  Has Online delivery  \
# 0                  1100                  1                    0
# 1                  1200                  1                    0
# 2                  4000                  1                    0
# 3                  1500                  0                    0
# 4                  1500                  1                    0
#
#    Is delivering now  Switch to order menu  Price range
# 0                  0                     0            3
# 1                  0                     0            3
# 2                  0                     0            4
# 3                  0                     0            4
# 4                  0                     0            4

# %%
import statsmodels.api as sm

# %%
print(sm.OLS(y, X).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:       Aggregate rating   R-squared (uncentered):                   0.787
# Model:                            OLS   Adj. R-squared (uncentered):              0.787
# Method:                 Least Squares   F-statistic:                              7061.
# Date:                Sat, 27 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        09:08:47   Log-Likelihood:                         -16846.
# No. Observations:                9542   AIC:                                  3.370e+04
# Df Residuals:                    9537   BIC:                                  3.374e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                            coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------
# ...

# %%
X = X[['Has Table booking', 'Has Online delivery','Price range']]

# %%
X
# Out:
#       Has Table booking  Has Online delivery  Price range
# 0                     1                    0            3
# 1                     1                    0            3
# 2                     1                    0            4
# 3                     0                    0            4
# 4                     1                    0            4
# ...                 ...                  ...          ...
# 9546                  0                    0            3
# 9547                  0                    0            3
# 9548                  0                    0            4
# 9549                  0                    0            4
# 9550                  0                    0            2
#
# [9542 rows x 3 columns]

# %%
print(sm.OLS(y, X).fit().summary())
# Out:
#                                  OLS Regression Results
# ...
# Dep. Variable:       Aggregate rating   R-squared (uncentered):                   0.787
# Model:                            OLS   Adj. R-squared (uncentered):              0.787
# Method:                 Least Squares   F-statistic:                          1.177e+04
# Date:                Sat, 27 Jul 2024   Prob (F-statistic):                        0.00
# Time:                        09:08:47   Log-Likelihood:                         -16848.
# No. Observations:                9542   AIC:                                  3.370e+04
# Df Residuals:                    9539   BIC:                                  3.372e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...
